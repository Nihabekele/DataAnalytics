# %%
print('hello world')
# Out:
# hello world

# %%
customer_id = "C-1221" 

customer_name = "Emily Jone" 

customer_gender = "Female" 

customer_dob = "01/01/1978" 

license_number = "VA-1234567" 

policy_number = "9876543"

# %%
print(customer_name)
# Out:
# Emily Jone

# %%
print(customer_id,customer_gender,customer_dob)
# Out:
# C-1221 Female 01/01/1978
